# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
 
X, y= make_blobs(n_samples=210, centers=3, n_features=2, cluster_std=0.8, shuffle=True,random_state=0)

plt.scatter(X[:,0], X[:,1], c='red', marker='x')

# %%
kmeans = KMeans(n_clusters=5, init='random', n_init="auto", random_state=0)
kmeans.fit_predict(X)

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(kmeans.inertia_)
# Out:
# 184.13812452852528

# %%
kmeans = KMeans(n_clusters=3, init='random', n_init="auto", random_state=0)
kmeans.fit_predict(X)

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(kmeans.inertia_)
# Out:
# 248.2261195843334

# %%
for k in [2,3,4,5,6]:
    kmeans = KMeans(n_clusters=k, init='random', n_init="auto", random_state=0)
    kmeans.fit_predict(X)
    
    plt.figure(figsize=(6,5))
    plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
                color='blue', label='Centers')
    plt.legend(loc='best')
    plt.xlabel('X0')
    plt.ylabel('X1')
    
    print(kmeans.inertia_)
# Out:
# 569.853022678921
# 248.2261195843334
# 211.89708301118216
# 184.13812452852528
# 159.80709756494826

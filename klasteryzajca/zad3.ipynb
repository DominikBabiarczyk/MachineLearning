# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
 
X, y= make_blobs(n_samples=210, centers=3, n_features=2, cluster_std=1, shuffle=True,random_state=0)

plt.scatter(X[:,0], X[:,1], c='red', marker='x')

kmeans = KMeans(n_clusters=3, init='k-means++', n_init="auto", random_state=1223)
kmeans.fit_predict(X)

plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
            color='blue', label='Centers')
plt.legend(loc='best')
plt.xlabel('X0')
plt.ylabel('X1')

print(kmeans.inertia_)
# Out:
# 364.58589436996084

# %%
for i in range(4):
    plt.figure(1)
    X, y= make_blobs(n_samples=210, centers=3, n_features=2, cluster_std=1, shuffle=True,random_state=i)
    
    # plt.scatter(X[:,0], X[:,1], c='red', marker='x')
    
    kmeans = KMeans(n_clusters=3, init='k-means++', n_init="auto", random_state=0)
    kmeans.fit_predict(X)
    
    plt.figure(2)
    plt.figure(figsize=(6,5))
    plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
                color='blue', label='Centers')
    plt.legend(loc='best')
    plt.xlabel('X0')
    plt.ylabel('X1')
    
    print(kmeans.inertia_)
# Out:
# 364.58589436996084
# 408.4326298145618
# 422.55721952150725
# 434.3955768652396

# %%
for i in range(4):
    plt.figure(1)
    X, y= make_blobs(n_samples=210, centers=3, n_features=2, cluster_std=1, shuffle=True,random_state=0)
    
    # plt.scatter(X[:,0], X[:,1], c='red', marker='x')
    
    kmeans = KMeans(n_clusters=3, init='k-means++', n_init="auto",max_iter=10,tol=1, random_state=10000)
    kmeans.fit_predict(X)
    
    plt.figure(2)
    plt.figure(figsize=(6,5))
    plt.scatter(X[:,0], X[:,1], s=70, c=kmeans.labels_, cmap=plt.cm.prism) 
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=200,
                color='blue', label='Centers')
    plt.legend(loc='best')
    plt.xlabel('X0')
    plt.ylabel('X1')
    
    print(kmeans.inertia_)
# Out:
# 380.7952289582264
# 380.7952289582264
# 380.7952289582264
# 380.7952289582264
